# %%
import pandas as pd

# %%
df_covid=pd.read_csv("/Users/rociocuestapedraz/Desktop/proyecto covid/200504COVID19MEXICO.csv",encoding= 'unicode_escape')

# %%
df_covid.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          04/05/2020      1ab4e5       2       3          25     2
# 1          04/05/2020      0cc140       2       3          15     1
# 2          04/05/2020      0e0689       2       3          27     1
# 3          04/05/2020      1b81dc       2       3           2     1
# 4          04/05/2020      0b7b4d       2       3          27     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... CARDIOVASCULAR  \
# 0           25           25              6              2  ...              2
# 1           28           15             20              1  ...              2
# 2           27           27              4              1  ...              2
# 3            8            2              4              1  ...              2
# 4           27           27              3              2  ...              2
#
#   OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  \
# ...

# %%
df_catalogos=pd.read_excel("/Users/rociocuestapedraz/Desktop/proyecto covid/Catalogos_0412.xlsx")
df_catalogos.head(10)
# Out:
#    CLAVE      DESCRIPCIÓN
# 0      1            USMER
# 1      2   FUERA DE USMER
# 2     99  NO ESPECIFICADO

# %%
df_CE=pd.read_csv("/Users/rociocuestapedraz/Desktop/proyecto covid/CoordEstados.csv",encoding= 'unicode_escape')
df_CE.head()
# Out:
#    Clave Estado                Estado      Latitud      Longitud Error
# 0             1        Aguascalientes      21.8818      -102.291    ok
# 1             2       Baja California        29.95   -115.116667    ok
# 2             3   Baja California Sur    25.625057   -111.700684    ok
# 3             4              Campeche  19.32920555  -89.94391483    ok
# 4             5  Coahuila De Zaragoza     27.32622   -102.163658    ok

# %%
df_CM=pd.read_csv("/Users/rociocuestapedraz/Desktop/proyecto covid/CoordMunicipios.csv",encoding= 'unicode_escape')
df_CM.head()
# Out:
#    Clave Estado          Estado  Clave Municipio       Municipio    Latitud  \
# 0           1.0  Aguascalientes              1.0  Aguascalientes  21.880655
# 1           1.0  Aguascalientes              2.0        Asientos  22.132107
# 2           1.0  Aguascalientes              3.0        Calvillo  21.846512
# 3           1.0  Aguascalientes              4.0           Cosío  22.370515
# 4           1.0  Aguascalientes              5.0     Jesús María  21.934555
#
#        Longitud  Error
# 0  -102.2961323    NaN
# 1  -102.0952559    NaN
# 2  -102.7185731    NaN
# 3  -102.3120085    NaN
# 4  -102.4684517    NaN

# %%
df_des=pd.read_excel("/Users/rociocuestapedraz/Desktop/proyecto covid/Descriptores_0412.xlsx")
df_des
# Out:
#     Nº   NOMBRE DE VARIABLE  \
# 0    1  FECHA_ACTUALIZACION
# 1    2               ORIGEN
# 2    3               SECTOR
# 3    4           ENTIDAD_UM
# 4    5                 SEXO
# 5    6          ENTIDAD_NAC
# 6    7          ENTIDAD_RES
# 7    8        MUNICIPIO_RES
# 8    9        TIPO_PACIENTE
# 9   10        FECHA_INGRESO
# 10  11       FECHA_SINTOMAS
# 11  12            FECHA_DEF
# 12  13             INTUBADO
# 13  14             NEUMONIA
# 14  15                 EDAD
# 15  16         NACIONALIDAD
# 16  17             EMBARAZO
# 17  18   HABLA_LENGUA_INDIG
# 18  19             DIABETES
# 19  20                 EPOC
# 20  21                 ASMA
# 21  22             INMUSUPR
# 22  23         HIPERTENSION
# 23  24            OTRAS_COM
# 24  25       CARDIOVASCULAR
# 25  26             OBESIDAD
# 26  27        RENAL_CRONICA
# 27  28           TABAQUISMO
# 28  29            OTRO_CASO
# 29  30            RESULTADO
# 30  31             MIGRANTE
# 31  32    PAIS_NACIONALIDAD
# ...

# %%
df_mex=pd.read_json("/Users/rociocuestapedraz/Desktop/proyecto covid/mexico.json",sep=', ')
df_mex
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-72fb171596e0> in <module>
# ----> 1 df_mex=pd.read_json("/Users/rociocuestapedraz/Desktop/proyecto covid/mexico.json",sep=', ')
#       2 df_mex
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# TypeError: read_json() got an unexpected keyword argument 'sep'
